# %% [markdown]
# For quick notes or queries, visit:
# - [Instagram | kparse_code](https://www.instagram.com/kparse_code/)
# - [Youtube | kparse_code](https://www.youtube.com/channel/UCGuhk1P1OA0X_7Ar2-xadEw)

# %% [markdown]
# ---
# ---
# # Worksheet: Bias-Variance in Supervised Learning
# **Total Marks: 25**
# **Level: Beginner–Intermediate**
# **Purpose: Self-Study Practice**
#
# ---
# ---
#
# ## Part 1: Conceptual Questions (10 points)
#
# ---
#
# ### 🔢Q1. [5 points] — Understanding
#
# Fill in the following table to compare how different levels of **bias** and **variance** affect key aspects of a model's performance and design.
#
# | Aspect            | High Bias                            | Low Bias                             | High Variance                          | Low Variance                         |
# |-------------------|----------------------------------------|----------------------------------------|-----------------------------------------|----------------------------------------|
# | Model Complexity  |                                        |                                        |                                         |                                        |
# | Model Flexibility |                                        |                                        |                                         |                                        |
# | Training Error    |                                        |                                        |                                         |                                        |
# | Test Error        |                                        |                                        |                                         |                                        |
#
#
# ✍️ _Complete the table with short, accurate phrases. Use it to reason through model performance issues._

# %% [markdown]
# ---
# ### 🔢Q2. [5 points] — Reasoning
#
# You are comparing two models on the same dataset:
# - Model A has high training and test error.
# - Model B has low training error but very high test error.
#
# Answer the following:
# - Which model has higher **bias**?
# - Which model has higher **variance**?
# - Which model would benefit from **more training data**?
#
# ✍️ _Write your answer below:_

# %% [markdown]
# ---
# ---
# ## Part 2: Numerical Questions (10 points)
#
# ---
#
# ### 🔢Q3. [5 points] — Bias-Variance Calculation
#
# A ridge regression model is trained with different λ values. The bias-variance analysis shows:
#
# | λ | Bias² | Variance | Total Error |
# |---|-------|----------|-------------|
# | 0.01 | 2.1 | 8.3 | ? |
# | 0.1 | 3.2 | 5.7 | ? |
# | 1.0 | 5.8 | 2.9 | ? |
# | 10.0 | 12.4 | 1.1 | ? |
#
# Given irreducible error = 1.2, complete the table and determine:
# - a) Optimal λ value
# - b) At what λ does bias become the dominant source of error?
# - c) Calculate the bias-variance ratio for λ = 0.1
#
# Use the formula:
# $$
# \text{Total Error} = \text{Bias}^2 + \text{Variance} + \text{Irreducible Error}
# $$
#
# ✍️ _Calculate the expected total test error:_

# %% [markdown]
# ---
# ### 🔢Q4. [5 points] — Bias-Variance Calculation
#
#  A model has the following error components:
# - Bias² = 4
# - Variance = 3
# - Irreducible Error = 2
#
# a) Compute the **expected test MSE**.
# b) If variance increases to 5, what is the new MSE?
#
#
# ✍️ _Write your answer below:_

# %% [markdown]
# ---
# ---
# ## Part 3: Code/Plot Question (5 points)
#
# ---
#
# ### 🔢Q5. [5 points] — Compare Models of Different Complexity
#
# Run the following code to compare bias and variance visually by fitting linear and polynomial models to noisy data.

# %%
import matplotlib.pyplot as plt

# Simulated model complexity and corresponding errors
model_complexity = [1, 2, 3, 4, 5, 6, 7, 8]
training_error = [8, 6, 4, 3, 2, 1.5, 1.2, 1]
validation_error = [9, 7, 5, 4, 4.5, 5.5, 7, 9]

# Plotting the errors
plt.figure(figsize=(8, 4))
plt.plot(model_complexity, training_error, label="Training Error", marker='o')
plt.plot(model_complexity, validation_error, label="Validation Error", marker='o')

# Adding vertical lines for regions
plt.axvline(x=2.5, color='gray', linestyle='--', label='Low/Med Boundary')
plt.axvline(x=5.5, color='gray', linestyle='--', label='Med/High Boundary')

# Labels and title
plt.xlabel("Model Complexity")
plt.ylabel("Error")
# plt.title("Bias–Variance Trade-off (with Complexity Regions)")
plt.legend()
plt.grid(True)

# Text labels for regions
plt.text(1, 9.5, "Low\nComplexity", ha='center', fontsize=10, color='gray')
plt.text(4, 9.5, "Medium\nComplexity", ha='center', fontsize=10, color='gray')
plt.text(7, 9.5, "High\nComplexity", ha='center', fontsize=10, color='gray')

plt.show()

# %% [markdown]
# The plot shows how training and validation error change with increasing model complexity.
#
# a) Based on the plot, complete the table below:
#
# | Model Complexity | Bias Level (High/Low) | Variance Level (High/Low) |
# |------------------|------------------------|-----------------------------|
# | Low              |                        |                             |
# | Medium           |                        |                             |
# | High             |                        |                             |
#
# b) In a few lines, explain how model complexity affects bias and variance.
#
# ✍️ Use trends in training and validation errors to support your answer.
#
# ---
# ---

# %% [markdown]
# ---
# ---
# ## ✅ Score Tracker
#
# | Question | Points | Scored |
# |----------|--------|--------|
# | Q1       | 5      |        |
# | Q2       | 5      |        |
# | Q3       | 5      |        |
# | Q4       | 5      |        |
# | Q5       | 5      |        |
# | **Total**| **25** |        |
#
# ---
# ---

# %% [markdown]
# ## Notes & Disclaimer
# •	 For quick notes or queries, visit:
# - [Instagram | kparse_code](https://www.instagram.com/kparse_code/)
# - [Youtube | kparse_code](https://www.youtube.com/channel/UCGuhk1P1OA0X_7Ar2-xadEw)
#
# •	Related Resources:
#  - Google Colab – to run Python code online without installing anything
#  - StatQuest: https://www.youtube.com/@statquest/playlists
#  - 3Blue1Brown: https://www.youtube.com/@3blue1brown/playlists
#  - Numerical: https://www.youtube.com/@MaheshHuddar/playlists
#
# •	Want more worksheets like this?
#  Try using AI prompt like:
#  - “Create a beginner-level machine learning worksheet with 2 conceptual questions(with sub-questions), 2 numerical, and 1 code-completion exercise on [topic(s)]"
#
# •	How to Use This Worksheet:
#   - These worksheets are designed for self-study and concept reinforcement.
#   - Try to solve without looking up the answers first.
#   - Use a notebook or Python IDE to experiment — code is the best teacher!
#   - Feel free to modify or extend questions as your understanding grows.
#
# •	Disclaimer:
# This worksheet is for self study & educational purposes only. Accuracy of content may vary depending on updates to libraries or definitions. Always refer to official documentation or textbooks for exam-level prep.
#
# ---
# ---
