# %% [markdown]
# For quick notes or queries, visit:
# - [Instagram | kparse_code](https://www.instagram.com/kparse_code/)
# - [Youtube | kparse_code](https://www.youtube.com/channel/UCGuhk1P1OA0X_7Ar2-xadEw)

# %% [markdown]
# ---
# ---
# # Worksheet: Bias-Variance in Supervised Learning
# **Total Marks: 25**
# **Level: Beginner–Intermediate**
# **Purpose: Self-Study Practice**
#
# ---
# ---
#
# ## Part 1: Conceptual Questions (10 points)
#
# ---

# %% [markdown]
# ### 🔢 Q1. [5 points] Theory: Reducing Bias and Variance
#
# Complete the table below to compare **high bias** and **high variance** problems in supervised learning, and suggest **specific solutions** for each.
#
# | Aspect                         | High Bias                                | High Variance                              |
# |-------------------------------|-------------------------------------------|---------------------------------------------|
# | a) Key symptoms                |                                           |                                             |
# | b) Performance characteristics (Train/Test error) |                                           |                                             |
# | c1) Model-level solution       | What model changes can reduce the issue? | What model simplification or control helps?|
# | c2) Data-level solution        | What can you do with the data to improve? | How can you make better use of data?       |
# | c3) Training/Regularization    | Any adjustments to training settings or regularization? | Any regularization that might help? |

# %% [markdown]
# ---
# ### 🔢 Q2. [5 points] — Reasoning
#
# You are developing a supervised learning model in multiple iterations. After each change, you observe the following:
#
# - **Iteration 1**: Linear regression model → High train and test error.
# - **Iteration 2**: Polynomial regression (degree 5) → Very low train error, high test error.
# - **Iteration 3**: Ridge regression (degree 5, λ = 0.5) → Slightly higher train error, reduced test error.
#
# Answer the following:
#
# a) What was the main issue in Iteration 1?
# b) What problem did you introduce in Iteration 2 while trying to fix Iteration 1?
# c) How did Ridge regression help in Iteration 3?

# %% [markdown]
# ---
# ---
# ## Part 2: Numerical Questions (10 points)
#
# ---

# %% [markdown]
# ### 🔢 Q3. [5 points] Bias-Variance Decomposition at a Single Point
#
# A regression model is trained multiple times on different datasets. For a particular input \( x_0 \), the following statistics are recorded:
#
# | Quantity                                | Value   |
# |----------------------------------------|---------|
# | True value $( \theta = f(x_0) )$       | 8.0     |
# | Expected prediction $( \mathbb{E}[\hat{\theta}] )$ | 6.5     |
# | Prediction variance $( \text{Var}[\hat{\theta}] )$ | 1.2     |
# | Irreducible error $( \sigma^2 )$       | 0.3     |
#
# Tasks
#
# **a)** Calculate the **squared bias** using:
#
# $[
# \text{Bias}^2 = \left( \mathbb{E}[\hat{\theta}] - \theta \right)^2
# ]$
#
# **b)** Compute the **total expected error** using:
#
# $[
# \mathbb{E}\left[ (\hat{\theta} - \theta)^2 \right] = \text{Bias}^2 + \text{Var}[\hat{\theta}] + \sigma^2
# ]$

# %% [markdown]
# ---
# ### 🔢 Q4. [5 points]Evaluating the Effect of Bias and Variance Reduction Techniques
#
# You are training a regression model on a dataset and observe the following statistics **before and after applying regularization**:
#
# | Metric                            | Before Regularization | After Regularization |
# |----------------------------------|------------------------|-----------------------|
# | Mean Prediction $( \mathbb{E}[\hat{\theta}] )$ | 5.5                    | 6.8                   |
# | True Value $( \theta )$                       | 7.0                    | 7.0                   |
# | Prediction Variance                          | 3.0                    | 1.2                   |
# | Irreducible Error $( \sigma^2 )$             | 0.5                    | 0.5                   |
#
#
#  Tasks:
#
# **a)** Compute the squared bias for both models:
# $[
# \text{Bias}^2 = \left( \mathbb{E}[\hat{\theta}] - \theta \right)^2
# ]$
#
# **b)** Compute the total expected error for both models using:
# $[
# \mathbb{E}[(\hat{\theta} - \theta)^2] = \text{Bias}^2 + \text{Variance} + \sigma^2
# ]$
#
# **c)** Compute the error reduction after applying regularization:
# $[
# \text{Error Reduction} = \text{Total Error}_{\text{Before}} - \text{Total Error}_{\text{After}}
# ]$
# What is the numerical value of this reduction?

# %% [markdown]
# ---
# ---
# ## Part 3: Code/Plot Question (5 points)
#
# ---

# %% [markdown]
# ### 💻 Q5. Code Completion: Estimate Bias and Variance from Simulation (5 points)
#
# You are given code that simulates repeated training of a regression model to estimate prediction **bias and variance** at a fixed input value `x0 = 1.5`. Some parts of the code are missing — complete them to compute:
#
# - The **mean prediction** at `x0`
# - The **bias** using the known true function value
# - The **variance** of the predictions

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.utils import resample

np.random.seed(42)
X_full = np.linspace(0, 1, 100).reshape(-1, 1)
y_true = np.sin(2 * np.pi * X_full).ravel()

plt.figure(figsize=(8, 4))
for _ in range(15):
    # Simulate random training data
    X = np.linspace(0, 1, 20).reshape(-1, 1)
    y = np.sin(2 * np.pi * X).ravel() + np.random.normal(0, 0.3, size=20)

    # Bootstrap sample
    X_sample, y_sample = resample(X, y)
    model = LinearRegression()
    model.fit(X_sample, y_sample)

    # Predict and plot
    y_pred = model.predict(X_full)
    plt.plot(X_full, y_pred, color='red', alpha=0.3)

# Plot true function
plt.plot(X_full, y_true, 'k--', label='True Function')
plt.title("Model Predictions vs True Function")
plt.legend()
plt.show()

# %% [markdown]
# 1. Does the average of red curves follow the true function well?
# If yes, the bias is low, else high.
#
# 2. Do the red curves vary a lot from one another?
# If yes, the variance is high, else low.
#
# 3. Based on your observations, does this model have high bias, high variance, both, or neither?

# %% [markdown]
# ---
# ---
# ## ✅ Score Tracker
#
# | Question | Points | Scored |
# |----------|--------|--------|
# | Q1       | 5      |        |
# | Q2       | 5      |        |
# | Q3       | 5      |        |
# | Q4       | 5      |        |
# | Q5       | 5      |        |
# | **Total**| **25** |        |
#
# ---
# ---

# %% [markdown]
# ## Notes & Disclaimer
# •	 For quick notes or queries, visit:
# - [Instagram | kparse_code](https://www.instagram.com/kparse_code/)
# - [Youtube | kparse_code](https://www.youtube.com/channel/UCGuhk1P1OA0X_7Ar2-xadEw)
#
# •	Related Resources:
#  - Google Colab – to run Python code online without installing anything
#  - StatQuest: https://www.youtube.com/@statquest/playlists
#  - 3Blue1Brown: https://www.youtube.com/@3blue1brown/playlists
#  - Numerical: https://www.youtube.com/@MaheshHuddar/playlists
#
# •	Want more worksheets like this?
#  Try using AI prompt like:
#  - “Create a beginner-level machine learning worksheet with 2 conceptual questions(with sub-questions), 2 numerical, and 1 code-completion exercise on [topic(s)]"
#
# •	How to Use This Worksheet:
#   - These worksheets are designed for self-study and concept reinforcement.
#   - Try to solve without looking up the answers first.
#   - Use a notebook or Python IDE to experiment — code is the best teacher!
#   - Feel free to modify or extend questions as your understanding grows.
#
# •	Disclaimer:
# This worksheet is for self study & educational purposes only. Accuracy of content may vary depending on updates to libraries or definitions. Always refer to official documentation or textbooks for exam-level prep.
#
# ---
# ---
